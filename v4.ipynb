# %%
from run_stacking import *
# Out:
# 2025-12-29 21:30:24.761266: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/petelin/AutoTSC/.venv/lib/python3.12/site-packages/keras/src/export/tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
dataset = 'CricketX'
dataset = 'GestureMidAirD1'
dataset = 'Meat'

X_train, y_train, X_test, y_test = utils.load_dataset(dataset)
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (60, 1, 448) (60,) (60, 1, 448) (60,)

# %%
s = StackerV4(random_state=270, n_repetitions=1, k_folds=10, time_limit_in_seconds=None)
s.fit(X_train, y_train)
# Out:
# [0.0000s] Starting fitting
# [0.2458s] Computed QUANT features in 0.2458s
# [0.2459s] Starting repetition 0
# [1.0583s] Computed MultiRocket features in 0.8124s
# [1.2693s] Computed Hydra features in 0.2108s
# [2.3690s] Computed RDST features in 1.0996s
# [3.8573s] Trained multirockethydra-ridgecv in 1.4864s for f-0/r-0
# [6.4331s] Trained multirockethydra-ridgecv in 2.5753s for f-1/r-0
# [8.9182s] Trained multirockethydra-ridgecv in 2.4848s for f-2/r-0
# [11.4260s] Trained multirockethydra-ridgecv in 2.5074s for f-3/r-0
# [14.0121s] Trained multirockethydra-ridgecv in 2.5856s for f-4/r-0
# [16.6002s] Trained multirockethydra-ridgecv in 2.5876s for f-5/r-0
# [19.3426s] Trained multirockethydra-ridgecv in 2.7418s for f-6/r-0
# [22.0250s] Trained multirockethydra-ridgecv in 2.6818s for f-7/r-0
# [24.6773s] Trained multirockethydra-ridgecv in 2.6517s for f-8/r-0
# [27.2362s] Trained multirockethydra-ridgecv in 2.5585s for f-9/r-0
# ...

# %%
#with utils.ray_init_or_reuse(num_cpus=24, resources={"meta": 100}, ignore_reinit_error=True):
pred = s.predict(X_test)
acc = accuracy_score(y_test, pred)
print(f'Accuracy on {dataset}: {acc}')

# %%
fgsg=Sgsdgsdg

# %%
random_state=270

# %%
s = MultiRocketHydraClassifier(random_state=random_state)
s.fit(X_train, y_train)

pred = s.predict(X_test)
acc = accuracy_score(y_test, pred)
print(f'Accuracy on {dataset}: {acc}')

# %%
#s = ContractableBOSS(random_state=random_state, n_jobs=-1, time_limit_in_minutes=0.3)
#s.fit(X_train, y_train)

#pred = s.predict(X_test)
#acc = accuracy_score(y_test, pred)
#print(f'Accuracy on {dataset}: {acc}')

# %%
s = RSTSF(random_state=random_state, n_jobs=-1, n_estimators=100)
s.fit(X_train, y_train)

pred = s.predict(X_test)
acc = accuracy_score(y_test, pred)
print(f'Accuracy on {dataset}: {acc}')

# %%
s = WEASEL_V2(random_state=random_state, n_jobs=-1)
s.fit(X_train, y_train)

pred = s.predict(X_test)
acc = accuracy_score(y_test, pred)
print(f'Accuracy on {dataset}: {acc}')

# %%
from aeon.classification.interval_based import QUANTClassifier
s = QUANTClassifier(random_state=random_state)
s.fit(X_train, y_train)

pred = s.predict(X_test)
acc = accuracy_score(y_test, pred)
print(f'Accuracy on {dataset}: {acc}')

# %%
from aeon.classification.hybrid import RISTClassifier
s = RISTClassifier(random_state=random_state, n_jobs=-1)
s.fit(X_train, y_train)

pred = s.predict(X_test)
acc = accuracy_score(y_test, pred)
print(f'Accuracy on {dataset}: {acc}')

# %%
from aeon.classification.interval_based import DrCIFClassifier
s = DrCIFClassifier(random_state=random_state, n_jobs=-1, time_limit_in_minutes=0.3)
s.fit(X_train, y_train)

pred = s.predict(X_test)
acc = accuracy_score(y_test, pred)
print(f'Accuracy on {dataset}: {acc}')

# %%
from aeon.classification.interval_based import DrCIFClassifier
s = DrCIFClassifier(random_state=random_state, n_jobs=-1, time_limit_in_minutes=3)
s.fit(X_train, y_train)

pred = s.predict(X_test)
acc = accuracy_score(y_test, pred)
print(f'Accuracy on {dataset}: {acc}')

# %%
from aeon.classification.shapelet_based import SASTClassifier
s = SASTClassifier(random_state=random_state, n_jobs=-1)
s.fit(X_train, y_train)

pred = s.predict(X_test)
acc = accuracy_score(y_test, pred)
print(f'Accuracy on {dataset}: {acc}')

# %%
from aeon.classification.interval_based import DrCIFClassifier
s = DrCIFClassifier(random_state=random_state, n_jobs=-1, time_limit_in_minutes=1)
v = s.fit_predict_proba(X_train, y_train)

pred = s.predict(X_test)
acc = accuracy_score(y_test, pred)
print(f'Accuracy on {dataset}: {acc}')

# %%
s._fit_predict_proba

# %%
# !uv pip install mrseql

# %%
from aeon.classification.dictionary_based import MrSEQLClassifier
s = MrSEQLClassifier()
s.fit(X_train, y_train)

pred = s.predict(X_test)
acc = accuracy_score(y_test, pred)
print(f'Accuracy on {dataset}: {acc}')

# %%
acc

# %%
dsfdfs=sdfsdf

# %%
from aeon.classification.deep_learning import LITETimeClassifier
s = LITETimeClassifier(verbose=True)
s.fit(X_train, y_train)

pred = s.predict(X_test)
acc = accuracy_score(y_test, pred)
print(f'Accuracy on {dataset}: {acc}')

# %%
# make large classficiation task and train ridgecv
X, y = np.random.rand(10000, 1000), np.random.randint(0, 5, size=(10000,))
clf = RidgeClassifierCV(alphas=np.logspace(-3, 3, 20))
clf.fit(X, y)
