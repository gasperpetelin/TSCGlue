# %%
import os
import random
from itertools import product

import matplotlib.pyplot as plt
import numpy as np
import polars as pl
from aeon.classification.convolution_based import RocketClassifier
from aeon.datasets.tsc_datasets import univariate
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from tqdm import tqdm

from autotsc import utils

# %%
write_dir = "experiments/automl_val_vs_test_correlation"
os.makedirs(write_dir, exist_ok=True)

datasets = list(univariate)  # [:15]
random.shuffle(datasets)
model_types = ["ridge", "randomforest"]  # , 'hgb', 'lda']

n_jobs = -1
n_runs = 5

# %%
def get_model(model_name):
    from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
    from sklearn.ensemble import HistGradientBoostingClassifier, RandomForestClassifier
    from sklearn.linear_model import RidgeClassifier

    if model_name == "ridge":
        alphas = np.logspace(-3, 3, 10)
        alpha = np.random.choice(alphas)
        model = RidgeClassifier(alpha=alpha)
        return RocketClassifier(estimator=model, n_jobs=-1)
    elif model_name == "randomforest":
        ccp_alphas = [0.0, 0.0001, 0.0005, 0.001, 0.005, 0.01, 0.05, 0.1]
        ccp_alpha = np.random.choice(ccp_alphas)
        model = RandomForestClassifier(n_jobs=n_jobs, ccp_alpha=ccp_alpha)
        return RocketClassifier(estimator=model, n_jobs=-1)
    elif model_name == "hgb":
        max_leaf_nodes_values = [4, 8, 15, 31, 47, 63, 95, 127, 191, 255]
        max_leaf_nodes = np.random.choice(max_leaf_nodes_values)
        model = HistGradientBoostingClassifier(max_leaf_nodes=max_leaf_nodes)
        return RocketClassifier(estimator=model, n_jobs=-1)
    elif model_name == "lda":
        model = LinearDiscriminantAnalysis()
        return RocketClassifier(estimator=model, n_jobs=-1)
    else:
        raise ValueError(f"Unknown model name: {model_name}")

# %%
all_combinations = list(product(datasets, range(n_runs), model_types))

last_dataset = None
X_train, y_train, X_test, y_test = None, None, None, None

for ds, run, model_name in tqdm(all_combinations, desc="Processing"):
    try:
        model = get_model(model_name)
        stats = {
            "dataset": ds,
            "run": run,
            "model": model_name,
        }

        hash_val = pl.DataFrame([stats]).hash_rows(seed=42, seed_1=1, seed_2=2, seed_3=3).item()
        file = f"{write_dir}/{hash_val}.parquet"

        if os.path.exists(file):
            print(f"Skipping {stats}")
            continue
        else:
            print(f"Processing {stats}")

        if ds != last_dataset:
            X_train, y_train, X_test, y_test = utils.load_dataset(ds)
            last_dataset = ds

        X_train_, X_val, y_train_, y_val = train_test_split(
            X_train, y_train, test_size=0.2, random_state=42
        )

        model.fit(X_train_, y_train_)
        y_val_pred = model.predict(X_val)
        val_accuracy = accuracy_score(y_val, y_val_pred)
        y_pred = model.predict(X_test)
        test_accuracy = accuracy_score(y_test, y_pred)

        stats["test_accuracy"] = test_accuracy
        stats["val_accuracy"] = val_accuracy

        df_stat = pl.DataFrame([stats])
        df_stat.write_parquet(file)

    except Exception as e:
        print(f"Error processing {ds}, run {run}, model {model_name}: {e}")
        continue
# Out:
# Processing:   6%|▌         | 75/1280 [00:00<00:01, 725.77it/s]
# Skipping {'dataset': 'AllGestureWiimoteY', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'AllGestureWiimoteY', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'AllGestureWiimoteY', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'AllGestureWiimoteY', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'AllGestureWiimoteY', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'AllGestureWiimoteY', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'AllGestureWiimoteY', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'AllGestureWiimoteY', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'AllGestureWiimoteY', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'AllGestureWiimoteY', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'ToeSegmentation1', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'ToeSegmentation1', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'ToeSegmentation1', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'ToeSegmentation1', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'ToeSegmentation1', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'ToeSegmentation1', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'ToeSegmentation1', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'ToeSegmentation1', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'ToeSegmentation1', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'ToeSegmentation1', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'DodgerLoopWeekend', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'DodgerLoopWeekend', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'DodgerLoopWeekend', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'DodgerLoopWeekend', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'DodgerLoopWeekend', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'DodgerLoopWeekend', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'DodgerLoopWeekend', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'DodgerLoopWeekend', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'DodgerLoopWeekend', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'DodgerLoopWeekend', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'BME', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'BME', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'BME', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'BME', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'BME', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'BME', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'BME', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'BME', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'BME', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'BME', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'TwoPatterns', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'TwoPatterns', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'TwoPatterns', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'TwoPatterns', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'TwoPatterns', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'TwoPatterns', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'TwoPatterns', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'TwoPatterns', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'TwoPatterns', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'TwoPatterns', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'Yoga', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'Yoga', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'Yoga', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'Yoga', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'Yoga', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'Yoga', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'Yoga', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'Yoga', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'Yoga', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'Yoga', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'GesturePebbleZ1', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'GesturePebbleZ1', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'GesturePebbleZ1', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'GesturePebbleZ1', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'GesturePebbleZ1', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'GesturePebbleZ1', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'GesturePebbleZ1', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'GesturePebbleZ1', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'GesturePebbleZ1', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'GesturePebbleZ1', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'InlineSkate', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'InlineSkate', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'InlineSkate', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'InlineSkate', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'InlineSkate', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'InlineSkate', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'InlineSkate', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'InlineSkate', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'InlineSkate', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'InlineSkate', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'Meat', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'Meat', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'Meat', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'Meat', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'Meat', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'Meat', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'Meat', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'Meat', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'Meat', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'Meat', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'SmoothSubspace', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'SmoothSubspace', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'SmoothSubspace', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'SmoothSubspace', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'SmoothSubspace', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'SmoothSubspace', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'SmoothSubspace', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'SmoothSubspace', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'SmoothSubspace', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'SmoothSubspace', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'ArrowHead', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'ArrowHead', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'ArrowHead', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'ArrowHead', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'ArrowHead', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'ArrowHead', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'ArrowHead', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'ArrowHead', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'ArrowHead', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'ArrowHead', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'DistalPhalanxOutlineCorrect', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'DistalPhalanxOutlineCorrect', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'DistalPhalanxOutlineCorrect', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'DistalPhalanxOutlineCorrect', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'DistalPhalanxOutlineCorrect', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'DistalPhalanxOutlineCorrect', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'DistalPhalanxOutlineCorrect', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'DistalPhalanxOutlineCorrect', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'DistalPhalanxOutlineCorrect', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'DistalPhalanxOutlineCorrect', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'RefrigerationDevices', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'RefrigerationDevices', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'RefrigerationDevices', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'RefrigerationDevices', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'RefrigerationDevices', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'RefrigerationDevices', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'RefrigerationDevices', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'RefrigerationDevices', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'RefrigerationDevices', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'RefrigerationDevices', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'PigAirwayPressure', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'PigAirwayPressure', 'run': 0, 'model': 'randomforest'}
# Processing:  16%|█▋        | 210/1280 [00:00<00:02, 504.70it/s]
# Skipping {'dataset': 'PigAirwayPressure', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'PigAirwayPressure', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'PigAirwayPressure', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'PigAirwayPressure', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'PigAirwayPressure', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'PigAirwayPressure', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'PigAirwayPressure', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'PigAirwayPressure', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'Haptics', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'Haptics', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'Haptics', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'Haptics', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'Haptics', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'Haptics', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'Haptics', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'Haptics', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'Haptics', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'Haptics', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'EthanolLevel', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'EthanolLevel', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'EthanolLevel', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'EthanolLevel', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'EthanolLevel', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'EthanolLevel', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'EthanolLevel', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'EthanolLevel', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'EthanolLevel', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'EthanolLevel', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'Herring', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'Herring', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'Herring', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'Herring', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'Herring', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'Herring', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'Herring', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'Herring', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'Herring', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'Herring', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'AllGestureWiimoteZ', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'AllGestureWiimoteZ', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'AllGestureWiimoteZ', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'AllGestureWiimoteZ', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'AllGestureWiimoteZ', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'AllGestureWiimoteZ', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'AllGestureWiimoteZ', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'AllGestureWiimoteZ', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'AllGestureWiimoteZ', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'AllGestureWiimoteZ', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'UWaveGestureLibraryZ', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'UWaveGestureLibraryZ', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'UWaveGestureLibraryZ', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'UWaveGestureLibraryZ', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'UWaveGestureLibraryZ', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'UWaveGestureLibraryZ', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'UWaveGestureLibraryZ', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'UWaveGestureLibraryZ', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'UWaveGestureLibraryZ', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'UWaveGestureLibraryZ', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'FacesUCR', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'FacesUCR', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'FacesUCR', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'FacesUCR', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'FacesUCR', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'FacesUCR', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'FacesUCR', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'FacesUCR', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'FacesUCR', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'FacesUCR', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'ECG200', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'ECG200', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'ECG200', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'ECG200', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'ECG200', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'ECG200', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'ECG200', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'ECG200', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'ECG200', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'ECG200', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'Car', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'Car', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'Car', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'Car', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'Car', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'Car', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'Car', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'Car', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'Car', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'Car', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'Worms', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'Worms', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'Worms', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'Worms', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'Worms', 'run': 2, 'model': 'ridge'}
# Processing:  31%|███       | 394/1280 [00:00<00:01, 723.47it/s]
# Skipping {'dataset': 'Worms', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'Worms', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'Worms', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'Worms', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'Worms', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'ProximalPhalanxOutlineAgeGroup', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'ProximalPhalanxOutlineAgeGroup', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'ProximalPhalanxOutlineAgeGroup', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'ProximalPhalanxOutlineAgeGroup', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'ProximalPhalanxOutlineAgeGroup', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'ProximalPhalanxOutlineAgeGroup', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'ProximalPhalanxOutlineAgeGroup', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'ProximalPhalanxOutlineAgeGroup', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'ProximalPhalanxOutlineAgeGroup', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'ProximalPhalanxOutlineAgeGroup', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'Beef', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'Beef', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'Beef', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'Beef', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'Beef', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'Beef', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'Beef', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'Beef', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'Beef', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'Beef', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'InsectEPGSmallTrain', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'InsectEPGSmallTrain', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'InsectEPGSmallTrain', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'InsectEPGSmallTrain', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'InsectEPGSmallTrain', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'InsectEPGSmallTrain', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'InsectEPGSmallTrain', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'InsectEPGSmallTrain', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'InsectEPGSmallTrain', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'InsectEPGSmallTrain', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'DodgerLoopGame', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'DodgerLoopGame', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'DodgerLoopGame', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'DodgerLoopGame', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'DodgerLoopGame', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'DodgerLoopGame', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'DodgerLoopGame', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'DodgerLoopGame', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'DodgerLoopGame', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'DodgerLoopGame', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'PLAID', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'PLAID', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'PLAID', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'PLAID', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'PLAID', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'PLAID', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'PLAID', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'PLAID', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'PLAID', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'PLAID', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'Mallat', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'Mallat', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'Mallat', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'Mallat', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'Mallat', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'Mallat', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'Mallat', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'Mallat', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'Mallat', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'Mallat', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'AllGestureWiimoteX', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'AllGestureWiimoteX', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'AllGestureWiimoteX', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'AllGestureWiimoteX', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'AllGestureWiimoteX', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'AllGestureWiimoteX', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'AllGestureWiimoteX', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'AllGestureWiimoteX', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'AllGestureWiimoteX', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'AllGestureWiimoteX', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'MiddlePhalanxTW', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'MiddlePhalanxTW', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'MiddlePhalanxTW', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'MiddlePhalanxTW', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'MiddlePhalanxTW', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'MiddlePhalanxTW', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'MiddlePhalanxTW', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'MiddlePhalanxTW', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'MiddlePhalanxTW', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'MiddlePhalanxTW', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'CinCECGTorso', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'CinCECGTorso', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'CinCECGTorso', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'CinCECGTorso', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'CinCECGTorso', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'CinCECGTorso', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'CinCECGTorso', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'CinCECGTorso', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'CinCECGTorso', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'CinCECGTorso', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'InsectEPGRegularTrain', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'InsectEPGRegularTrain', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'InsectEPGRegularTrain', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'InsectEPGRegularTrain', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'InsectEPGRegularTrain', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'InsectEPGRegularTrain', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'InsectEPGRegularTrain', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'InsectEPGRegularTrain', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'InsectEPGRegularTrain', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'InsectEPGRegularTrain', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'CricketY', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'CricketY', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'CricketY', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'CricketY', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'CricketY', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'CricketY', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'CricketY', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'CricketY', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'CricketY', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'CricketY', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'HandOutlines', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'HandOutlines', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'HandOutlines', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'HandOutlines', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'HandOutlines', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'HandOutlines', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'HandOutlines', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'HandOutlines', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'HandOutlines', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'HandOutlines', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'PowerCons', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'PowerCons', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'PowerCons', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'PowerCons', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'PowerCons', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'PowerCons', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'PowerCons', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'PowerCons', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'PowerCons', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'PowerCons', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'Chinatown', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'Chinatown', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'Chinatown', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'Chinatown', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'Chinatown', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'Chinatown', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'Chinatown', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'Chinatown', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'Chinatown', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'Chinatown', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'SonyAIBORobotSurface2', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'SonyAIBORobotSurface2', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'SonyAIBORobotSurface2', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'SonyAIBORobotSurface2', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'SonyAIBORobotSurface2', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'SonyAIBORobotSurface2', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'SonyAIBORobotSurface2', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'SonyAIBORobotSurface2', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'SonyAIBORobotSurface2', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'SonyAIBORobotSurface2', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'ScreenType', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'ScreenType', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'ScreenType', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'ScreenType', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'ScreenType', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'ScreenType', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'ScreenType', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'ScreenType', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'ScreenType', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'ScreenType', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'DistalPhalanxTW', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'DistalPhalanxTW', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'DistalPhalanxTW', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'DistalPhalanxTW', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'DistalPhalanxTW', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'DistalPhalanxTW', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'DistalPhalanxTW', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'DistalPhalanxTW', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'DistalPhalanxTW', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'DistalPhalanxTW', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'GesturePebbleZ2', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'GesturePebbleZ2', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'GesturePebbleZ2', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'GesturePebbleZ2', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'GesturePebbleZ2', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'GesturePebbleZ2', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'GesturePebbleZ2', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'GesturePebbleZ2', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'GesturePebbleZ2', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'GesturePebbleZ2', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'Wine', 'run': 0, 'model': 'ridge'}
# Processing:  49%|████▉     | 633/1280 [00:00<00:00, 1000.91it/s]
# Skipping {'dataset': 'Wine', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'Wine', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'Wine', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'Wine', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'Wine', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'Wine', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'Wine', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'Wine', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'Wine', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'EOGVerticalSignal', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'EOGVerticalSignal', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'EOGVerticalSignal', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'EOGVerticalSignal', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'EOGVerticalSignal', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'EOGVerticalSignal', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'EOGVerticalSignal', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'EOGVerticalSignal', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'EOGVerticalSignal', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'EOGVerticalSignal', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'UWaveGestureLibraryY', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'UWaveGestureLibraryY', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'UWaveGestureLibraryY', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'UWaveGestureLibraryY', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'UWaveGestureLibraryY', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'UWaveGestureLibraryY', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'UWaveGestureLibraryY', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'UWaveGestureLibraryY', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'UWaveGestureLibraryY', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'UWaveGestureLibraryY', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'ToeSegmentation2', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'ToeSegmentation2', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'ToeSegmentation2', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'ToeSegmentation2', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'ToeSegmentation2', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'ToeSegmentation2', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'ToeSegmentation2', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'ToeSegmentation2', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'ToeSegmentation2', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'ToeSegmentation2', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'Coffee', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'Coffee', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'Coffee', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'Coffee', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'Coffee', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'Coffee', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'Coffee', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'Coffee', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'Coffee', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'Coffee', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'Trace', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'Trace', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'Trace', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'Trace', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'Trace', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'Trace', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'Trace', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'Trace', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'Trace', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'Trace', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'Wafer', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'Wafer', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'Wafer', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'Wafer', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'Wafer', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'Wafer', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'Wafer', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'Wafer', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'Wafer', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'Wafer', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'GestureMidAirD2', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'GestureMidAirD2', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'GestureMidAirD2', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'GestureMidAirD2', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'GestureMidAirD2', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'GestureMidAirD2', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'GestureMidAirD2', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'GestureMidAirD2', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'GestureMidAirD2', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'GestureMidAirD2', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'UWaveGestureLibraryX', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'UWaveGestureLibraryX', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'UWaveGestureLibraryX', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'UWaveGestureLibraryX', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'UWaveGestureLibraryX', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'UWaveGestureLibraryX', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'UWaveGestureLibraryX', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'UWaveGestureLibraryX', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'UWaveGestureLibraryX', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'UWaveGestureLibraryX', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'DistalPhalanxOutlineAgeGroup', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'DistalPhalanxOutlineAgeGroup', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'DistalPhalanxOutlineAgeGroup', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'DistalPhalanxOutlineAgeGroup', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'DistalPhalanxOutlineAgeGroup', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'DistalPhalanxOutlineAgeGroup', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'DistalPhalanxOutlineAgeGroup', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'DistalPhalanxOutlineAgeGroup', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'DistalPhalanxOutlineAgeGroup', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'DistalPhalanxOutlineAgeGroup', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'Lightning7', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'Lightning7', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'Lightning7', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'Lightning7', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'Lightning7', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'Lightning7', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'Lightning7', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'Lightning7', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'Lightning7', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'Lightning7', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'PigArtPressure', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'PigArtPressure', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'PigArtPressure', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'PigArtPressure', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'PigArtPressure', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'PigArtPressure', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'PigArtPressure', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'PigArtPressure', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'PigArtPressure', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'PigArtPressure', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'Strawberry', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'Strawberry', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'Strawberry', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'Strawberry', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'Strawberry', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'Strawberry', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'Strawberry', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'Strawberry', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'Strawberry', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'Strawberry', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'NonInvasiveFetalECGThorax1', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'NonInvasiveFetalECGThorax1', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'NonInvasiveFetalECGThorax1', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'NonInvasiveFetalECGThorax1', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'NonInvasiveFetalECGThorax1', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'NonInvasiveFetalECGThorax1', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'NonInvasiveFetalECGThorax1', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'NonInvasiveFetalECGThorax1', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'NonInvasiveFetalECGThorax1', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'NonInvasiveFetalECGThorax1', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'MixedShapesRegularTrain', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'MixedShapesRegularTrain', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'MixedShapesRegularTrain', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'MixedShapesRegularTrain', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'MixedShapesRegularTrain', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'MixedShapesRegularTrain', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'MixedShapesRegularTrain', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'MixedShapesRegularTrain', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'MixedShapesRegularTrain', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'MixedShapesRegularTrain', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'GunPointMaleVersusFemale', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'GunPointMaleVersusFemale', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'GunPointMaleVersusFemale', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'GunPointMaleVersusFemale', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'GunPointMaleVersusFemale', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'GunPointMaleVersusFemale', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'GunPointMaleVersusFemale', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'GunPointMaleVersusFemale', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'GunPointMaleVersusFemale', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'GunPointMaleVersusFemale', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'StarLightCurves', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'StarLightCurves', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'StarLightCurves', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'StarLightCurves', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'StarLightCurves', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'StarLightCurves', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'StarLightCurves', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'StarLightCurves', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'StarLightCurves', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'StarLightCurves', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'InsectWingbeatSound', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'InsectWingbeatSound', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'InsectWingbeatSound', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'InsectWingbeatSound', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'InsectWingbeatSound', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'InsectWingbeatSound', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'InsectWingbeatSound', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'InsectWingbeatSound', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'InsectWingbeatSound', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'InsectWingbeatSound', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'GunPointOldVersusYoung', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'GunPointOldVersusYoung', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'GunPointOldVersusYoung', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'GunPointOldVersusYoung', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'GunPointOldVersusYoung', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'GunPointOldVersusYoung', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'GunPointOldVersusYoung', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'GunPointOldVersusYoung', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'GunPointOldVersusYoung', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'GunPointOldVersusYoung', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'FordA', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'FordA', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'FordA', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'FordA', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'FordA', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'FordA', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'FordA', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'FordA', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'FordA', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'FordA', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'Symbols', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'Symbols', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'Symbols', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'Symbols', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'Symbols', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'Symbols', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'Symbols', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'Symbols', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'Symbols', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'Symbols', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'MelbournePedestrian', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'MelbournePedestrian', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'MelbournePedestrian', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'MelbournePedestrian', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'MelbournePedestrian', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'MelbournePedestrian', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'MelbournePedestrian', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'MelbournePedestrian', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'MelbournePedestrian', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'MelbournePedestrian', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'PhalangesOutlinesCorrect', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'PhalangesOutlinesCorrect', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'PhalangesOutlinesCorrect', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'PhalangesOutlinesCorrect', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'PhalangesOutlinesCorrect', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'PhalangesOutlinesCorrect', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'PhalangesOutlinesCorrect', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'PhalangesOutlinesCorrect', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'PhalangesOutlinesCorrect', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'PhalangesOutlinesCorrect', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'SemgHandGenderCh2', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'SemgHandGenderCh2', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'SemgHandGenderCh2', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'SemgHandGenderCh2', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'SemgHandGenderCh2', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'SemgHandGenderCh2', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'SemgHandGenderCh2', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'SemgHandGenderCh2', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'SemgHandGenderCh2', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'SemgHandGenderCh2', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'ShapeletSim', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'ShapeletSim', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'ShapeletSim', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'ShapeletSim', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'ShapeletSim', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'ShapeletSim', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'ShapeletSim', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'ShapeletSim', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'ShapeletSim', 'run': 4, 'model': 'ridge'}
# Processing:  58%|█████▊    | 737/1280 [00:00<00:00, 898.66it/s]
# Skipping {'dataset': 'ShapeletSim', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'WordSynonyms', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'WordSynonyms', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'WordSynonyms', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'WordSynonyms', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'WordSynonyms', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'WordSynonyms', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'WordSynonyms', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'WordSynonyms', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'WordSynonyms', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'WordSynonyms', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'UMD', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'UMD', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'UMD', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'UMD', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'UMD', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'UMD', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'UMD', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'UMD', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'UMD', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'UMD', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'ProximalPhalanxOutlineCorrect', 'run': 0, 'model': 'ridge'}
# ...
# Skipping {'dataset': 'Rock', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'Rock', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'BirdChicken', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'BirdChicken', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'BirdChicken', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'BirdChicken', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'BirdChicken', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'BirdChicken', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'BirdChicken', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'BirdChicken', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'BirdChicken', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'BirdChicken', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'PickupGestureWiimoteZ', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'PickupGestureWiimoteZ', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'PickupGestureWiimoteZ', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'PickupGestureWiimoteZ', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'PickupGestureWiimoteZ', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'PickupGestureWiimoteZ', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'PickupGestureWiimoteZ', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'PickupGestureWiimoteZ', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'PickupGestureWiimoteZ', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'PickupGestureWiimoteZ', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'OliveOil', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'OliveOil', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'OliveOil', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'OliveOil', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'OliveOil', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'OliveOil', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'OliveOil', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'OliveOil', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'OliveOil', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'OliveOil', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'ECGFiveDays', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'ECGFiveDays', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'ECGFiveDays', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'ECGFiveDays', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'ECGFiveDays', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'ECGFiveDays', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'ECGFiveDays', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'ECGFiveDays', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'ECGFiveDays', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'ECGFiveDays', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'DodgerLoopDay', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'DodgerLoopDay', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'DodgerLoopDay', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'DodgerLoopDay', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'DodgerLoopDay', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'DodgerLoopDay', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'DodgerLoopDay', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'DodgerLoopDay', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'DodgerLoopDay', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'DodgerLoopDay', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'FiftyWords', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'FiftyWords', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'FiftyWords', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'FiftyWords', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'FiftyWords', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'FiftyWords', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'FiftyWords', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'FiftyWords', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'FiftyWords', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'FiftyWords', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'PigCVP', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'PigCVP', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'PigCVP', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'PigCVP', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'PigCVP', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'PigCVP', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'PigCVP', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'PigCVP', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'PigCVP', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'PigCVP', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'FordB', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'FordB', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'FordB', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'FordB', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'FordB', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'FordB', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'FordB', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'FordB', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'FordB', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'FordB', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'GunPointAgeSpan', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'GunPointAgeSpan', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'GunPointAgeSpan', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'GunPointAgeSpan', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'GunPointAgeSpan', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'GunPointAgeSpan', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'GunPointAgeSpan', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'GunPointAgeSpan', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'GunPointAgeSpan', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'GunPointAgeSpan', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'OSULeaf', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'OSULeaf', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'OSULeaf', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'OSULeaf', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'OSULeaf', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'OSULeaf', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'OSULeaf', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'OSULeaf', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'OSULeaf', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'OSULeaf', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'UWaveGestureLibraryAll', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'UWaveGestureLibraryAll', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'UWaveGestureLibraryAll', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'UWaveGestureLibraryAll', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'UWaveGestureLibraryAll', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'UWaveGestureLibraryAll', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'UWaveGestureLibraryAll', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'UWaveGestureLibraryAll', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'UWaveGestureLibraryAll', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'UWaveGestureLibraryAll', 'run': 4, 'model': 'randomforest'}
# Processing: 100%|██████████| 1280/1280 [00:01<00:00, 799.11it/s]
# Skipping {'dataset': 'MedicalImages', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'MedicalImages', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'MedicalImages', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'MedicalImages', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'MedicalImages', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'MedicalImages', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'MedicalImages', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'MedicalImages', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'MedicalImages', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'MedicalImages', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'MiddlePhalanxOutlineCorrect', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'MiddlePhalanxOutlineCorrect', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'MiddlePhalanxOutlineCorrect', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'MiddlePhalanxOutlineCorrect', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'MiddlePhalanxOutlineCorrect', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'MiddlePhalanxOutlineCorrect', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'MiddlePhalanxOutlineCorrect', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'MiddlePhalanxOutlineCorrect', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'MiddlePhalanxOutlineCorrect', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'MiddlePhalanxOutlineCorrect', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'WormsTwoClass', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'WormsTwoClass', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'WormsTwoClass', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'WormsTwoClass', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'WormsTwoClass', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'WormsTwoClass', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'WormsTwoClass', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'WormsTwoClass', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'WormsTwoClass', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'WormsTwoClass', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'Crop', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'Crop', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'Crop', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'Crop', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'Crop', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'Crop', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'Crop', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'Crop', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'Crop', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'Crop', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'SemgHandSubjectCh2', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'SemgHandSubjectCh2', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'SemgHandSubjectCh2', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'SemgHandSubjectCh2', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'SemgHandSubjectCh2', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'SemgHandSubjectCh2', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'SemgHandSubjectCh2', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'SemgHandSubjectCh2', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'SemgHandSubjectCh2', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'SemgHandSubjectCh2', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'DiatomSizeReduction', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'DiatomSizeReduction', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'DiatomSizeReduction', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'DiatomSizeReduction', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'DiatomSizeReduction', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'DiatomSizeReduction', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'DiatomSizeReduction', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'DiatomSizeReduction', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'DiatomSizeReduction', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'DiatomSizeReduction', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'FaceAll', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'FaceAll', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'FaceAll', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'FaceAll', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'FaceAll', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'FaceAll', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'FaceAll', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'FaceAll', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'FaceAll', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'FaceAll', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'Ham', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'Ham', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'Ham', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'Ham', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'Ham', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'Ham', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'Ham', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'Ham', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'Ham', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'Ham', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'ACSF1', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'ACSF1', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'ACSF1', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'ACSF1', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'ACSF1', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'ACSF1', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'ACSF1', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'ACSF1', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'ACSF1', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'ACSF1', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'ProximalPhalanxTW', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'ProximalPhalanxTW', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'ProximalPhalanxTW', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'ProximalPhalanxTW', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'ProximalPhalanxTW', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'ProximalPhalanxTW', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'ProximalPhalanxTW', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'ProximalPhalanxTW', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'ProximalPhalanxTW', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'ProximalPhalanxTW', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'CBF', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'CBF', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'CBF', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'CBF', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'CBF', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'CBF', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'CBF', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'CBF', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'CBF', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'CBF', 'run': 4, 'model': 'randomforest'}
# Skipping {'dataset': 'SonyAIBORobotSurface1', 'run': 0, 'model': 'ridge'}
# Skipping {'dataset': 'SonyAIBORobotSurface1', 'run': 0, 'model': 'randomforest'}
# Skipping {'dataset': 'SonyAIBORobotSurface1', 'run': 1, 'model': 'ridge'}
# Skipping {'dataset': 'SonyAIBORobotSurface1', 'run': 1, 'model': 'randomforest'}
# Skipping {'dataset': 'SonyAIBORobotSurface1', 'run': 2, 'model': 'ridge'}
# Skipping {'dataset': 'SonyAIBORobotSurface1', 'run': 2, 'model': 'randomforest'}
# Skipping {'dataset': 'SonyAIBORobotSurface1', 'run': 3, 'model': 'ridge'}
# Skipping {'dataset': 'SonyAIBORobotSurface1', 'run': 3, 'model': 'randomforest'}
# Skipping {'dataset': 'SonyAIBORobotSurface1', 'run': 4, 'model': 'ridge'}
# Skipping {'dataset': 'SonyAIBORobotSurface1', 'run': 4, 'model': 'randomforest'}

# %%
df = pl.read_parquet(f"{write_dir}/*.parquet")
df
# Out:
# shape: (7_271, 5)
# ┌────────────────────────────────┬─────┬──────────────┬───────────────┬──────────────┐
# │ dataset                        ┆ run ┆ model        ┆ test_accuracy ┆ val_accuracy │
# │ ---                            ┆ --- ┆ ---          ┆ ---           ┆ ---          │
# │ str                            ┆ i64 ┆ str          ┆ f64           ┆ f64          │
# ╞════════════════════════════════╪═════╪══════════════╪═══════════════╪══════════════╡
# │ HouseTwenty                    ┆ 3   ┆ lda          ┆ 0.907563      ┆ 1.0          │
# │ ProximalPhalanxOutlineAgeGroup ┆ 7   ┆ lda          ┆ 0.321951      ┆ 0.325        │
# │ MiddlePhalanxTW                ┆ 6   ┆ randomforest ┆ 0.603896      ┆ 0.6          │
# │ NonInvasiveFetalECGThorax2     ┆ 3   ┆ hgb          ┆ 0.922137      ┆ 0.913889     │
# │ ItalyPowerDemand               ┆ 13  ┆ randomforest ┆ 0.960155      ┆ 0.928571     │
# │ …                              ┆ …   ┆ …            ┆ …             ┆ …            │
# │ PigArtPressure                 ┆ 9   ┆ hgb          ┆ 0.826923      ┆ 0.380952     │
# │ Earthquakes                    ┆ 1   ┆ lda          ┆ 0.467626      ┆ 0.523077     │
# │ RefrigerationDevices           ┆ 11  ┆ randomforest ┆ 0.490667      ┆ 0.626667     │
# │ Beef                           ┆ 10  ┆ randomforest ┆ 0.633333      ┆ 0.5          │
# │ FaceFour                       ┆ 14  ┆ hgb          ┆ 0.159091      ┆ 0.2          │
# └────────────────────────────────┴─────┴──────────────┴───────────────┴──────────────┘

# %%
def categorize_model(model: str) -> str:
    if "ridge" in model.lower():
        return "ridge"
    elif "forest" in model.lower():
        return "randomforest"
    elif "histgradientboosting" in model.lower() or "hgb" in model.lower():
        return "hgb"
    elif "lda" in model.lower():
        return "lda"
    else:
        return "other"


df = df.with_columns(
    pl.col("model").map_elements(categorize_model, return_dtype=pl.Utf8).alias("model_type")
)
df
# Out:
# shape: (7_271, 6)
# ┌───────────────────────────────┬─────┬──────────────┬───────────────┬──────────────┬──────────────┐
# │ dataset                       ┆ run ┆ model        ┆ test_accuracy ┆ val_accuracy ┆ model_type   │
# │ ---                           ┆ --- ┆ ---          ┆ ---           ┆ ---          ┆ ---          │
# │ str                           ┆ i64 ┆ str          ┆ f64           ┆ f64          ┆ str          │
# ╞═══════════════════════════════╪═════╪══════════════╪═══════════════╪══════════════╪══════════════╡
# │ HouseTwenty                   ┆ 3   ┆ lda          ┆ 0.907563      ┆ 1.0          ┆ lda          │
# │ ProximalPhalanxOutlineAgeGrou ┆ 7   ┆ lda          ┆ 0.321951      ┆ 0.325        ┆ lda          │
# │ p                             ┆     ┆              ┆               ┆              ┆              │
# │ MiddlePhalanxTW               ┆ 6   ┆ randomforest ┆ 0.603896      ┆ 0.6          ┆ randomforest │
# │ NonInvasiveFetalECGThorax2    ┆ 3   ┆ hgb          ┆ 0.922137      ┆ 0.913889     ┆ hgb          │
# │ ItalyPowerDemand              ┆ 13  ┆ randomforest ┆ 0.960155      ┆ 0.928571     ┆ randomforest │
# │ …                             ┆ …   ┆ …            ┆ …             ┆ …            ┆ …            │
# │ PigArtPressure                ┆ 9   ┆ hgb          ┆ 0.826923      ┆ 0.380952     ┆ hgb          │
# │ Earthquakes                   ┆ 1   ┆ lda          ┆ 0.467626      ┆ 0.523077     ┆ lda          │
# │ RefrigerationDevices          ┆ 11  ┆ randomforest ┆ 0.490667      ┆ 0.626667     ┆ randomforest │
# │ Beef                          ┆ 10  ┆ randomforest ┆ 0.633333      ┆ 0.5          ┆ randomforest │
# │ FaceFour                      ┆ 14  ┆ hgb          ┆ 0.159091      ┆ 0.2          ┆ hgb          │
# └───────────────────────────────┴─────┴──────────────┴───────────────┴──────────────┴──────────────┘

# %%
df["model"].unique()
# Out:
# shape: (4,)
# Series: 'model' [str]
# [
# 	"lda"
# 	"hgb"
# 	"randomforest"
# 	"ridge"
# ]

# %%
import seaborn as sns

fig, axs = plt.subplots(ncols=3, nrows=(len(datasets) + 3) // 3, figsize=(15, 75))
axs = axs.flatten()
for ds_ in datasets:
    df_ds = df.filter(pl.col("dataset") == ds_).sort("model")
    ax = axs[datasets.index(ds_)]
    sns.scatterplot(
        data=df_ds.to_pandas(), x="val_accuracy", y="test_accuracy", ax=ax, hue="model_type"
    )
    ax.set_title(ds_)
    ax.set_xlabel("Validation Accuracy")
    ax.set_ylabel("Test Accuracy")
plt.tight_layout()

# %%
120 // 3
# Out:
# 40
