# %%
import numpy as np
from aeon.classification.interval_based import RSTSF
from sklearn.metrics import accuracy_score
from tscglue.models import LokyStackerV7, LokyStackerV7SoftFilterRidge, TSCGlue, LokyStackerV10FM, LokyStackerV10Base, LokyStackerV10TabICL
from tscglue import utils, data_loader
import polars as pl
from sklearn.metrics import log_loss, roc_auc_score

# %%
dataset = "Worms"
# dataset = 'Car'
# dataset = 'HandOutlines'
# dataset = 'Trace'
# dataset = 'SwedishLeaf'
# dataset = 'Meat'
X_train, y_train, X_test, y_test = data_loader.load_fold(dataset, 0)
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (181, 1, 900) (181,) (77, 1, 900) (77,)

# %%
seed = 24

# %%
m = LokyStackerV10FM(random_state=seed, n_jobs=16, keep_features=True, verbose=10, n_repetitions=1)
m.fit(X_train, y_train)
# Out:
# [0.00s] Starting fit, run_dir=tscglue_runs/72375cac5534447b, n_jobs=16
# [0.00s] Saved X and y to disk in 0.00s
# 2026-03-19 15:02:32.266809: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [9.35s] Computed multirocket_s_1993785632 features (181, 49728) (34.34 MB) in 0.6368s
# [11.06s] Computed hydra_s_102238865 features torch.Size([181, 7168]) (4.95 MB) in 1.7050s
# [13.08s] Computed quant features (181, 7987) (5.51 MB) in 2.0170s
# [17.64s] Computed rdst_s_1870295790 features (181, 30000) (41.43 MB) in 4.5645s
# [22.86s] Computed mantis features (181, 512) (0.35 MB) in 5.2222s
# [44.58s] Computed chronos2 features (181, 1536) (1.06 MB) in 21.7162s
# [44.59s] Starting training with 16 workers for 50 models
# ...
